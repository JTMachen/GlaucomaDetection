# %%
import tensorflow as tf
import os
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3, ResNet50, Xception, VGG19, VGG16
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np

full_path = r'{}'.format(os.getcwd())
TRAIN_PATH = full_path + r"\Train"
VAL_PATH = full_path + r"\Validation"
TEST_PATH = full_path + r"\Test"

batch_size = 16
epochs = 25
IMG_HEIGHT = 300
IMG_WIDTH = 300

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

validation_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

# Load Data
train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    VAL_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

optimizers = {
    'sgd': {
        "Name": "Stochastic Gradient Descent"
    },
    'adam': {
        "Name": "Adam"
    },
    'rmsprop': {
        "Name": "RMSprop (Root Mean Square Propagation)"
    },
    'adagrad': {
        "Name": "Adagrad (Adaptive Gradient Algorithm)"
    },
    'adadelta': {
        "Name": "Adadelta"
    },
    'nadam': {
        "Name": "Nadam"
    },
    'ftrl': {
        "Name": "FTRL (Follow The Regularized Leader)"
    }
}

models = ['InceptionV3','VGG16','VGG19','Xception','Vanilla']

def buildModel(model, opt):
    if model == "InceptionV3":
        base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    elif model == "Vanilla":
        base_model = Sequential([Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH ,3)), MaxPooling2D(), Dropout(0.2), Conv2D(32, 3, padding='same', activation='relu'), MaxPooling2D(), Conv2D(64, 3, padding='same', activation='relu'), MaxPooling2D(), Dropout(0.2)])
    elif model == "VGG16":
        base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    elif model == "VGG19":
        base_model = VGG19(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    elif model == "Xception":
        base_model = Xception(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))
    
    # Add custom top layers for binary classification
    x = base_model.output
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(128, activation='relu')(x)
    predictions = keras.layers.Dense(1, activation='sigmoid')(x)

    # Combine the base model and custom top layers
    model = keras.Model(inputs=base_model.input, outputs=predictions)

    # Freeze the layers of the base model
    for layer in base_model.layers:
        layer.trainable = False
        
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    # Train the Model
    history = model.fit(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=epochs,
        validation_data=validation_generator,
        validation_steps=len(validation_generator),
        verbose=0
    )

    print()
    print()
    test_loss, test_accuracy = model.evaluate(test_generator, steps=len(test_generator))
    print(f"Test Accuracy: {round(test_accuracy * 100, 2)}%")

    val_predictions = model.predict(test_generator)

    # Apply a threshold to convert predictions to class labels (0 or 1)
    val_labels = (val_predictions > 0.5).astype(int)

    # Get the true labels from the validation data generator
    val_true_labels = test_generator.classes

    # Generate the classification report
    class_names = ['0', '1']
    report = classification_report(val_true_labels, val_labels, target_names=class_names)

    # Print the classification report
    print(report)

    validation_predictions = model.predict(test_generator)
    predicted_classes = (validation_predictions > 0.5).astype(int)
    true_classes = test_generator.classes

    # Calculate the confusion matrix
    confusion = confusion_matrix(true_classes, predicted_classes)

    # Create a heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion, annot=True, fmt='d', cmap='YlGnBu', linewidths=0.5, xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
    print()
    return

for model in models:
    print(model)
    print()
    for opt in optimizers:
        print(optimizers[opt]['Name'])
        buildModel(model,opt)
# Out:
# Found 402 images belonging to 2 classes.
# Found 201 images belonging to 2 classes.
# Found 102 images belonging to 2 classes.
# InceptionV3
#
# Stochastic Gradient Descent
#
#
# 7/7 [==============================] - 4s 496ms/step - loss: 0.1470 - accuracy: 0.9314
# Test Accuracy: 93.14%
# 7/7 [==============================] - 4s 468ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        51
#            1       0.98      0.88      0.93        51
#
#     accuracy                           0.93       102
#    macro avg       0.94      0.93      0.93       102
# weighted avg       0.94      0.93      0.93       102
#
# 7/7 [==============================] - 3s 468ms/step
# Adam
#
#
# 7/7 [==============================] - 3s 450ms/step - loss: 0.7110 - accuracy: 0.9216
# Test Accuracy: 92.16%
# 7/7 [==============================] - 4s 442ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91        51
#            1       0.86      1.00      0.93        51
#
#     accuracy                           0.92       102
#    macro avg       0.93      0.92      0.92       102
# weighted avg       0.93      0.92      0.92       102
#
# 7/7 [==============================] - 3s 445ms/step
# RMSprop (Root Mean Square Propagation)
#
#
# 7/7 [==============================] - 4s 495ms/step - loss: 0.1542 - accuracy: 0.9412
# Test Accuracy: 94.12%
# 7/7 [==============================] - 4s 455ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        51
#            1       0.96      0.92      0.94        51
#
#     accuracy                           0.94       102
#    macro avg       0.94      0.94      0.94       102
# weighted avg       0.94      0.94      0.94       102
#
# 7/7 [==============================] - 3s 458ms/step
# Adagrad (Adaptive Gradient Algorithm)
#
#
# 7/7 [==============================] - 4s 505ms/step - loss: 0.0956 - accuracy: 0.9608
# Test Accuracy: 96.08%
# 7/7 [==============================] - 4s 473ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        51
#            1       0.96      0.96      0.96        51
#
#     accuracy                           0.96       102
#    macro avg       0.96      0.96      0.96       102
# weighted avg       0.96      0.96      0.96       102
#
# 7/7 [==============================] - 3s 458ms/step
# Adadelta
#
#
# 7/7 [==============================] - 4s 485ms/step - loss: 0.1460 - accuracy: 0.9706
# Test Accuracy: 97.06%
# 7/7 [==============================] - 4s 461ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        51
#            1       0.94      1.00      0.97        51
#
#     accuracy                           0.97       102
#    macro avg       0.97      0.97      0.97       102
# weighted avg       0.97      0.97      0.97       102
#
# 7/7 [==============================] - 3s 461ms/step
# Nadam
#
#
# 7/7 [==============================] - 3s 443ms/step - loss: 0.2724 - accuracy: 0.9314
# Test Accuracy: 93.14%
# 7/7 [==============================] - 4s 435ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.93        51
#            1       0.88      1.00      0.94        51
#
#     accuracy                           0.93       102
#    macro avg       0.94      0.93      0.93       102
# weighted avg       0.94      0.93      0.93       102
#
# 7/7 [==============================] - 3s 432ms/step
# FTRL (Follow The Regularized Leader)
#
#
# 7/7 [==============================] - 3s 466ms/step - loss: 0.1480 - accuracy: 0.9412
# Test Accuracy: 94.12%
# 7/7 [==============================] - 4s 450ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        51
#            1       0.92      0.96      0.94        51
#
#     accuracy                           0.94       102
#    macro avg       0.94      0.94      0.94       102
# weighted avg       0.94      0.94      0.94       102
#
# 7/7 [==============================] - 3s 453ms/step
# VGG16
#
# Stochastic Gradient Descent
#
#
# 7/7 [==============================] - 11s 2s/step - loss: 0.6988 - accuracy: 0.5000
# Test Accuracy: 50.0%
# 7/7 [==============================] - 12s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        51
#            1       0.50      1.00      0.67        51
#
#     accuracy                           0.50       102
#    macro avg       0.25      0.50      0.33       102
# weighted avg       0.25      0.50      0.33       102
#
# 7/7 [==============================] - 12s 2s/step
# Adam
#
#
# 7/7 [==============================] - 11s 2s/step - loss: 0.3521 - accuracy: 0.8725
# Test Accuracy: 87.25%
# 7/7 [==============================] - 11s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.88        51
#            1       0.97      0.76      0.86        51
#
#     accuracy                           0.87       102
#    macro avg       0.89      0.87      0.87       102
# weighted avg       0.89      0.87      0.87       102
#
# 7/7 [==============================] - 11s 2s/step
# RMSprop (Root Mean Square Propagation)
#
#
# 7/7 [==============================] - 11s 2s/step - loss: 0.3894 - accuracy: 0.8235
# Test Accuracy: 82.35%
# 7/7 [==============================] - 11s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.67      0.79        51
#            1       0.75      0.98      0.85        51
#
#     accuracy                           0.82       102
#    macro avg       0.86      0.82      0.82       102
# weighted avg       0.86      0.82      0.82       102
#
# 7/7 [==============================] - 11s 2s/step
# Adagrad (Adaptive Gradient Algorithm)
#
#
# 7/7 [==============================] - 11s 2s/step - loss: 0.5165 - accuracy: 0.7745
# Test Accuracy: 77.45%
# 7/7 [==============================] - 11s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.57      0.72        51
#            1       0.69      0.98      0.81        51
#
#     accuracy                           0.77       102
#    macro avg       0.83      0.77      0.76       102
# weighted avg       0.83      0.77      0.76       102
#
# 7/7 [==============================] - 11s 2s/step
# Adadelta
#
#
# 7/7 [==============================] - 30s 4s/step - loss: 0.6681 - accuracy: 0.5000
# Test Accuracy: 50.0%
# 7/7 [==============================] - 30s 4s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        51
#            1       0.50      1.00      0.67        51
#
#     accuracy                           0.50       102
#    macro avg       0.25      0.50      0.33       102
# weighted avg       0.25      0.50      0.33       102
#
# 7/7 [==============================] - 30s 4s/step
# Nadam
#
#
# 7/7 [==============================] - 25s 3s/step - loss: 0.1995 - accuracy: 0.9314
# Test Accuracy: 93.14%
# 7/7 [==============================] - 25s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        51
#            1       0.96      0.90      0.93        51
#
#     accuracy                           0.93       102
#    macro avg       0.93      0.93      0.93       102
# weighted avg       0.93      0.93      0.93       102
#
# 7/7 [==============================] - 25s 3s/step
# FTRL (Follow The Regularized Leader)
#
#
# 7/7 [==============================] - 21s 3s/step - loss: 0.7117 - accuracy: 0.5000
# Test Accuracy: 50.0%
# 7/7 [==============================] - 22s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        51
#            1       0.50      1.00      0.67        51
#
#     accuracy                           0.50       102
#    macro avg       0.25      0.50      0.33       102
# weighted avg       0.25      0.50      0.33       102
#
# 7/7 [==============================] - 21s 3s/step
# VGG19
#
# Stochastic Gradient Descent
#
#
# 7/7 [==============================] - 24s 3s/step - loss: 0.7241 - accuracy: 0.5000
# Test Accuracy: 50.0%
# 7/7 [==============================] - 24s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        51
#            1       0.50      1.00      0.67        51
#
#     accuracy                           0.50       102
#    macro avg       0.25      0.50      0.33       102
# weighted avg       0.25      0.50      0.33       102
#
# 7/7 [==============================] - 24s 3s/step
# Adam
#
#
# 7/7 [==============================] - 21s 3s/step - loss: 0.2123 - accuracy: 0.9216
# Test Accuracy: 92.16%
# 7/7 [==============================] - 21s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93        51
#            1       0.98      0.86      0.92        51
#
#     accuracy                           0.92       102
#    macro avg       0.93      0.92      0.92       102
# weighted avg       0.93      0.92      0.92       102
#
# 7/7 [==============================] - 21s 3s/step
# RMSprop (Root Mean Square Propagation)
#
#
# 7/7 [==============================] - 19s 3s/step - loss: 0.2610 - accuracy: 0.9118
# Test Accuracy: 91.18%
# 7/7 [==============================] - 20s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92        51
#            1       0.98      0.84      0.91        51
#
#     accuracy                           0.91       102
#    macro avg       0.92      0.91      0.91       102
# weighted avg       0.92      0.91      0.91       102
#
# 7/7 [==============================] - 19s 3s/step
# Adagrad (Adaptive Gradient Algorithm)
#
#
# 7/7 [==============================] - 14s 2s/step - loss: 0.4696 - accuracy: 0.8824
# Test Accuracy: 88.24%
# 7/7 [==============================] - 14s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87        51
#            1       0.84      0.94      0.89        51
#
#     accuracy                           0.88       102
#    macro avg       0.89      0.88      0.88       102
# weighted avg       0.89      0.88      0.88       102
#
# 7/7 [==============================] - 14s 2s/step
# Adadelta
#
#
# 7/7 [==============================] - 32s 4s/step - loss: 0.6261 - accuracy: 0.6275
# Test Accuracy: 62.75%
# 7/7 [==============================] - 32s 4s/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.41        51
#            1       0.57      1.00      0.73        51
#
#     accuracy                           0.63       102
#    macro avg       0.79      0.63      0.57       102
# weighted avg       0.79      0.63      0.57       102
#
# 7/7 [==============================] - 32s 4s/step
# Nadam
#
#
# 7/7 [==============================] - 27s 4s/step - loss: 0.2673 - accuracy: 0.9020
# Test Accuracy: 90.2%
# 7/7 [==============================] - 27s 4s/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91        51
#            1       0.98      0.82      0.89        51
#
#     accuracy                           0.90       102
#    macro avg       0.91      0.90      0.90       102
# weighted avg       0.91      0.90      0.90       102
#
# 7/7 [==============================] - 27s 4s/step
# FTRL (Follow The Regularized Leader)
#
#
# 7/7 [==============================] - 24s 3s/step - loss: 0.7133 - accuracy: 0.5000
# Test Accuracy: 50.0%
# 7/7 [==============================] - 24s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        51
#            1       0.50      1.00      0.67        51
#
#     accuracy                           0.50       102
#    macro avg       0.25      0.50      0.33       102
# weighted avg       0.25      0.50      0.33       102
#
# 7/7 [==============================] - 24s 3s/step
# Xception
#
# Stochastic Gradient Descent
#
#
# 7/7 [==============================] - 6s 784ms/step - loss: 0.1099 - accuracy: 0.9412
# Test Accuracy: 94.12%
# 7/7 [==============================] - 6s 769ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94        51
#            1       0.91      0.98      0.94        51
#
#     accuracy                           0.94       102
#    macro avg       0.94      0.94      0.94       102
# weighted avg       0.94      0.94      0.94       102
#
# 7/7 [==============================] - 6s 774ms/step
# Adam
#
#
# 7/7 [==============================] - 7s 958ms/step - loss: 0.0802 - accuracy: 0.9706
# Test Accuracy: 97.06%
# 7/7 [==============================] - 7s 944ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        51
#            1       0.98      0.96      0.97        51
#
#     accuracy                           0.97       102
#    macro avg       0.97      0.97      0.97       102
# weighted avg       0.97      0.97      0.97       102
#
# 7/7 [==============================] - 7s 941ms/step
# RMSprop (Root Mean Square Propagation)
#
#
# 7/7 [==============================] - 6s 895ms/step - loss: 0.2982 - accuracy: 0.9118
# Test Accuracy: 91.18%
# 7/7 [==============================] - 7s 858ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92        51
#            1       0.98      0.84      0.91        51
#
#     accuracy                           0.91       102
#    macro avg       0.92      0.91      0.91       102
# weighted avg       0.92      0.91      0.91       102
#
# 7/7 [==============================] - 6s 859ms/step
# Adagrad (Adaptive Gradient Algorithm)
#
#
# 7/7 [==============================] - 8s 1s/step - loss: 0.1097 - accuracy: 0.9608
# Test Accuracy: 96.08%
# 7/7 [==============================] - 9s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        51
#            1       0.98      0.94      0.96        51
#
#     accuracy                           0.96       102
#    macro avg       0.96      0.96      0.96       102
# weighted avg       0.96      0.96      0.96       102
#
# 7/7 [==============================] - 8s 1s/step
# Adadelta
#
#
# 7/7 [==============================] - 8s 1s/step - loss: 0.1914 - accuracy: 0.9412
# Test Accuracy: 94.12%
# 7/7 [==============================] - 8s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        51
#            1       0.92      0.96      0.94        51
#
#     accuracy                           0.94       102
#    macro avg       0.94      0.94      0.94       102
# weighted avg       0.94      0.94      0.94       102
#
# 7/7 [==============================] - 8s 1s/step
# Nadam
#
#
# 7/7 [==============================] - 8s 1s/step - loss: 0.1270 - accuracy: 0.9804
# Test Accuracy: 98.04%
# 7/7 [==============================] - 8s 1s/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        51
#            1       0.96      1.00      0.98        51
#
#     accuracy                           0.98       102
#    macro avg       0.98      0.98      0.98       102
# weighted avg       0.98      0.98      0.98       102
#
# 7/7 [==============================] - 8s 1s/step
# FTRL (Follow The Regularized Leader)
#
#
# 7/7 [==============================] - 8s 1s/step - loss: 0.2036 - accuracy: 0.9412
# Test Accuracy: 94.12%
# 7/7 [==============================] - 8s 1s/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        51
#            1       0.92      0.96      0.94        51
#
#     accuracy                           0.94       102
#    macro avg       0.94      0.94      0.94       102
# weighted avg       0.94      0.94      0.94       102
#
# 7/7 [==============================] - 8s 1s/step
# Vanilla
#
# Stochastic Gradient Descent
#
#
# 7/7 [==============================] - 1s 106ms/step - loss: 0.4897 - accuracy: 0.7549
# Test Accuracy: 75.49%
# 7/7 [==============================] - 1s 104ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.53      0.68        51
#            1       0.68      0.98      0.80        51
#
#     accuracy                           0.75       102
#    macro avg       0.82      0.75      0.74       102
# weighted avg       0.82      0.75      0.74       102
#
# 7/7 [==============================] - 1s 104ms/step
# Adam
#
#
# 7/7 [==============================] - 1s 104ms/step - loss: 0.3483 - accuracy: 0.8627
# Test Accuracy: 86.27%
# 7/7 [==============================] - 1s 102ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.88        51
#            1       0.97      0.75      0.84        51
#
#     accuracy                           0.86       102
#    macro avg       0.88      0.86      0.86       102
# weighted avg       0.88      0.86      0.86       102
#
# 7/7 [==============================] - 1s 103ms/step
# RMSprop (Root Mean Square Propagation)
#
#
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3930 - accuracy: 0.8824
# Test Accuracy: 88.24%
# 7/7 [==============================] - 1s 97ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.78      0.87        51
#            1       0.82      0.98      0.89        51
#
#     accuracy                           0.88       102
#    macro avg       0.90      0.88      0.88       102
# weighted avg       0.90      0.88      0.88       102
#
# 7/7 [==============================] - 1s 97ms/step
# Adagrad (Adaptive Gradient Algorithm)
#
#
# 7/7 [==============================] - 1s 97ms/step - loss: 0.5511 - accuracy: 0.7745
# Test Accuracy: 77.45%
# 7/7 [==============================] - 1s 96ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        51
#            1       0.69      1.00      0.82        51
#
#     accuracy                           0.77       102
#    macro avg       0.84      0.77      0.76       102
# weighted avg       0.84      0.77      0.76       102
#
# 7/7 [==============================] - 1s 97ms/step
# Adadelta
#
#
# 7/7 [==============================] - 1s 93ms/step - loss: 0.6098 - accuracy: 0.6569
# Test Accuracy: 65.69%
# 7/7 [==============================] - 1s 93ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.31      0.48        51
#            1       0.59      1.00      0.74        51
#
#     accuracy                           0.66       102
#    macro avg       0.80      0.66      0.61       102
# weighted avg       0.80      0.66      0.61       102
#
# 7/7 [==============================] - 1s 92ms/step
# Nadam
#
#
# 7/7 [==============================] - 1s 84ms/step - loss: 0.4890 - accuracy: 0.7353
# Test Accuracy: 73.53%
# 7/7 [==============================] - 1s 85ms/step
#               precision    recall  f1-score   support
#
#            0       0.66      0.96      0.78        51
#            1       0.93      0.51      0.66        51
#
#     accuracy                           0.74       102
#    macro avg       0.80      0.74      0.72       102
# weighted avg       0.80      0.74      0.72       102
#
# 7/7 [==============================] - 1s 86ms/step
# FTRL (Follow The Regularized Leader)
#
#
# 7/7 [==============================] - 1s 83ms/step - loss: 0.6929 - accuracy: 0.5000
# Test Accuracy: 50.0%
# 7/7 [==============================] - 1s 81ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        51
#            1       0.50      1.00      0.67        51
#
#     accuracy                           0.50       102
#    macro avg       0.25      0.50      0.33       102
# weighted avg       0.25      0.50      0.33       102
#
# 7/7 [==============================] - 1s 81ms/step
